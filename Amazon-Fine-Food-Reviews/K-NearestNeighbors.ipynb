# %% [markdown]
# KNN on Amazon Fine Food Reviews:
# By: Maddy
#
# KNN Approaches:
#     1. Brute Force
#     2. KD Tree
# Vectorize / Featurize method:
#     1. BOW
#     2. TFIDF
#     3. W2V
#     4. TFIDF W2V

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.cross_validation import cross_val_score
from collections import Counter
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn import cross_validation
from sklearn.metrics import f1_score
import sqlite3
import nltk
import string
import seaborn as sns
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import pickle
from sklearn.decomposition import TruncatedSVD
from tqdm import tqdm
import os

# %%
if os.path.isfile('final.sqlite'):
    conn = sqlite3.connect('final.sqlite')
    final = pd.read_sql_query(""" SELECT * FROM Reviews WHERE Score !=3 limit 80000""", conn)
    conn.close()
else:
    print("Please the above cell")

# %%
print (final.sort_values('Time'))
# Out:
#         index      Id   ProductId          UserId  \
# 0      138706  150524  0006641040   ACITT7DI6IDDL
# 30     138683  150501  0006641040   AJ46FKXOVC7NR
# 424    417839  451856  B00004CXX9   AIUWLEQ1ADEG5
# 330    346055  374359  B00004CI84  A344SMIA5JECGM
# 423    417838  451855  B00004CXX9   AJH6LUC1UT1ON
# 245    346116  374422  B00004CI84  A1048CYU0OV4O8
# 308    346041  374343  B00004CI84   A1B2IZU1JLZA6
# 215     70688   76882  B00002N8SM  A32DW342WBJ6BX
# 261    346141  374450  B00004CI84   ACJR7EQF9S6FP
# 325    346094  374400  B00004CI84  A2DEE7F9XKP3ZR
# 427    417883  451903  B00004CXX9  A2DEE7F9XKP3ZR
# 241      1146    1245  B00002Z754  A29Z5PI9BW2PU3
# 242      1145    1244  B00002Z754  A3B8RCEI0FXFI6
# 485    121041  131217  B00004RAMX   A5NQLNC6QPGSI
# 868    138017  149789  B00004S1C6  A1KXONFPU2XQ5K
# 837    138001  149770  B00004S1C5  A1KXONFPU2XQ5K
# 249    346115  374421  B00004CI84  A1FJOY14X3MUHE
# 296    346102  374408  B00004CI84  A1GB1Q193DNFGR
# 844    138000  149768  B00004S1C5   A7P76IGRZZBFJ
# 360    346078  374383  B00004CI84   A34NBH479RB0E
# 329    346054  374358  B00004CI84  A1HWMNSQF14MP8
# 845    138018  149790  B00004S1C6  A1IU7S4HCK1XK0
# 425    417901  451923  B00004CXX9   ANIMV3SPDD8SH
# 342    346037  374339  B00004CI84   AZRJH4JFB59VC
# 270    346140  374449  B00004CI84  A3K3YJWV0N54ZO
# 855    138020  149792  B00004S1C6  A3B5QJVM1TLYJG
# 353    346033  374335  B00004CI84  A3L5V40F14R2GP
# 32     138682  150500  0006641040  A1IJKK6Q1GTEAY
# 998    333930  361317  B00005IX96  A3ODTU118FKC5J
# 331    346032  374334  B00004CI84  A2HIZRVOKXKZ52
# ...       ...     ...         ...             ...
# 9663   219497  237940  B00018CWN4  A37264CFSSA73O
# 19228  167467  181575  B0005XNXB0  A36AUU1UNRS48G
# 11605  144868  157173  B0001IOSCM  A25YYMCNXA2RC0
# 21309  371715  401972  B0006349W6  A21BT40VZCCYT4
# 941    189914  205938  B00005C2M2  A3IVNUHADVJKFA
# 8351   302041  327141  B000158YDY  A2ZN3J0M6KIML9
# 42329  383031  414150  B000E3ZFCG  A1ABVE0J8C9SHM
# 42331  383032  414151  B000E3ZFCG  A2R5Y7T3JY15I9
# 25099  328309  355352  B0007PNKRS  A1TED4G0PWZPQV
# 585    192892  209140  B00004RAMY   AEQ2FUEQEQVTI
# 11521  106073  115167  B0001HAEKI   A289SYWE4BHCF
# 586    192891  209139  B00004RAMY  A24GR1MZXO4MOM
# 54086  316676  342848  B000ET4SM8  A1F0TERGQZ746P
# 23149  468409  506494  B0006UFY46   AEEVDQNVIH4SJ
# 50325  206620  223927  B000EMAZK4  A20DY4XPIV6YKR
# 72818  109587  118929  B000G1CG50  A3VBVJ6UG09MFC
# 50322  206619  223926  B000EMAZK4    A46U02M3QK02
# 72236  434221  469577  B000FZRYM2  A3L53GLROBET4F
# 15226  273030  295923  B0002DGL26  A3SZ0N66423CE5
# 1637   441646  477560  B000084ETY  A1HRYC60VTMYC0
# 23864  132267  143596  B0007A0AQM  A1HHNY1GVD3UIS
# 36415  152909  165819  B000CPZSC8   ABEPJJLWMXXTD
# 28970  405977  439023  B0009P5Y9I   A5R3XOLGJG1P5
# 12603  198769  215423  B0001UK0CM  A2V8WXAFG1TEOC
# 19643  409449  442827  B0005Z7GMA   ALJ8LNGJ8HC1V
# 16845  426410  461154  B0002NVKZ4   A94YB71KEDA3X
# 10048  390432  422146  B0001BH5YM   A1BZ3HMAKK0NC
# 16642   90340   98294  B0002LY6W0  A1BX08Y0GIT5RU
# 25593  352293  381088  B0007U5J40   AGCJI4YJM3PWZ
# 21198  483047  522300  B0006345OI  A21YJCM7MR97BS
#
#                                             ProfileName  HelpfulnessNumerator  \
# 0                                       shari zychinski                     0
# 30                                   Nicholas A Mesiano                     2
# 424                                    Elizabeth Medina                     0
# 330                                     Vincent P. Ross                     1
# 423                            The Phantom of the Opera                     0
# 245                                        Judy L. Eans                     2
# 308                                                 Wes                    19
# 215                                         Buttersugar                     0
# 261                                    Jeremy Robertson                     2
# 325                                              jerome                     0
# 427                                              jerome                     0
# 241                                              Robbie                     7
# 242                                           B G Chase                    10
# 485                                           Kim Nason                     7
# 868                                    Stephanie Manley                    26
# 837                                    Stephanie Manley                     8
# 249                                       Justin Howard                     2
# 296                                    Bruce Lee Pullen                     5
# 844                      E. Thompson "Soooooper Genius"                    18
# 360                                          "dmab6395"                     0
# 329                                   will@socialaw.com                     1
# 845                                      Joanna Daneman                    25
# 425                                    Guy De Federicis                     1
# 342                                    Lynwood E. Hines                    21
# 270                                                Joey                     2
# 855                                         Dan Crevier                    11
# 353                                               AARON                     0
# 32                                           A Customer                     2
# 998                                   Rosemarie E Smith                     5
# 331                                       KAY N. FOWLER                     0
# ...                                                 ...                   ...
# 9663                                             Andrea                     0
# 19228                                              seal                     0
# 11605                                            Libbia                     0
# 21309                                     Carol A. Reed                     0
# 941                               Krystalyn A Kirschner                     0
# 8351                                         Kristen A.                     0
# 42329                                              Gabe                     0
# 42331                                       Darley Ware                     0
# 25099                             Stellavera S. Kilcher                     0
# 585                                          heathcliff                     0
# 11521                                            akilah                     0
# 586                                                  MO                     0
# 54086                                    Lori E. "Lori"                     0
# 23149                                  Eugene M. Watson                     0
# 50325                                      Traci Weaver                     0
# 72818                                         Bignose30                     0
# 50322                       Cynthia &#34;Bellasmom&#34;                     0
# 72236                              W. J. Weise "Cashma"                     0
# 15226                                  Cynthia Z. Wrinn                     0
# 1637                                                Ace                     0
# 23864                                         boomstick                     0
# 36415                                    peachesandcake                     0
# 28970                                            Amanda                     0
# 12603                                       ronald (NY)                     0
# 19643                                      Susan Cobler                     0
# 16845                                               Joy                     0
# 10048                      Patricia Campbell "G.I JANE"                     0
# 16642  L. Nguyen "Always on the lookout for a good d...                     0
# 25593                                      CSCHULTE3069                     0
# 21198                                  deidre hamaguchi                     0
#
#        HelpfulnessDenominator     Score        Time  \
# 0                           0  positive   939340800
# 30                          2  positive   940809600
# 424                         0  positive   944092800
# 330                         2  positive   944438400
# 423                         0  positive   946857600
# 245                         2  positive   947376000
# 308                        23  negative   948240000
# 215                         0  positive   948672000
# 261                         3  positive   951523200
# 325                         3  positive   959990400
# 427                         1  positive   959990400
# 241                         7  positive   961718400
# 242                        10  positive   962236800
# 485                         8  positive   965001600
# 868                        28  positive   965779200
# 837                         8  positive   965779200
# 249                         2  positive   966297600
# 296                         5  positive   970531200
# 844                        18  positive   975974400
# 360                         1  positive   977184000
# 329                         2  positive   978134400
# 845                        27  positive   982800000
# 425                        12  negative   992217600
# 342                        23  negative   997228800
# 270                         3  positive  1001289600
# 855                        12  positive  1003795200
# 353                         0  positive  1004054400
# 32                          2  positive  1009324800
# 998                         7  positive  1010275200
# 331                         0  positive  1012780800
# ...                       ...       ...         ...
# 9663                        0  positive  1351209600
# 19228                       0  positive  1351209600
# 11605                       0  positive  1351209600
# 21309                       0  positive  1351209600
# 941                         0  positive  1351209600
# 8351                        0  positive  1351209600
# 42329                       0  positive  1351209600
# 42331                       0  positive  1351209600
# 25099                       0  positive  1351209600
# 585                         0  negative  1351209600
# 11521                       0  positive  1351209600
# 586                         0  positive  1351209600
# 54086                       0  positive  1351209600
# 23149                       0  positive  1351209600
# 50325                       0  positive  1351209600
# 72818                       0  positive  1351209600
# 50322                       0  positive  1351209600
# 72236                       0  positive  1351209600
# 15226                       0  negative  1351209600
# 1637                        0  positive  1351209600
# 23864                       0  positive  1351209600
# 36415                       0  positive  1351209600
# 28970                       0  positive  1351209600
# 12603                       0  positive  1351209600
# 19643                       0  positive  1351209600
# 16845                       0  positive  1351209600
# 10048                       0  positive  1351209600
# 16642                       0  positive  1351209600
# 25593                       0  positive  1351209600
# 21198                       0  positive  1351209600
#
#                                                  Summary  \
# 0                              EVERY book is educational
# 30     This whole series is great way to spend time w...
# 424                                 Entertainingl Funny!
# 330                              A modern day fairy tale
# 423                                           FANTASTIC!
# 245                                                GREAT
# 308      WARNING: CLAMSHELL EDITION IS EDITED TV VERSION
# 215                               A sure death for flies
# 261             Bettlejuice...Bettlejuice...BETTLEJUICE!
# 325        Research - Beatlejuice video - French version
# 427                                             Research
# 241                                        Great Product
# 242                       WOW Make your own 'slickers' !
# 485                             End your Gopher Problems
# 868                                         A must have!
# 837                                     Very easy to use
# 249    A fresh, original film from master storyteller...
# 296         Fabulous Comedic Fanasy Directed by a Master
# 844                                    Who Needs Wilton?
# 360                                                FUNNY
# 329                                  A Afterlife Success
# 845    Make your own Martha Stewart style cakes and c...
# 425                    CASPER IS THE GHOST WITH THE MOST
# 342                            Great movie, terrible DVD
# 270    Beetlejuice is a greatmovie, but they cheated ...
# 855                                 Nice, bright colors!
# 353               Beetlejuice! Beetlejuice! Beatlejuice!
# 32                                    It Was a favorite!
# 998                            A little piece of heaven.
# 331                Beetlejuice - Great Fun for Everyone!
# ...                                                  ...
# 9663                                      Great quality!
# 19228       Hands down, the best cajun seasoning.  Ever.
# 11605                               Simple and Authentic
# 21309                                Good Training Treat
# 941                                         Perfect Gift
# 8351                                       What a treat!
# 42329       Unbelievable! the best rice I have ever had.
# 42331                                  I love this stuff
# 25099                                   Came as expected
# 585                                     defective device
# 11521                                         Good stuff
# 586                                      Great Mole Trap
# 54086                           Homemade Vanilla Extract
# 23149                                       Great Salmon
# 50325                                         SO GOOD!!!
# 72818                                     Yummy Chummies
# 50322                                    FAVORITE tea...
# 72236                              Red Chili Fettuccinne
# 15226                                       plastic chew
# 1637                     Cee Cee LOOOVES it, This I Know
# 23864                    my dogs love the peanut butter!
# 36415                         Plump, juicy vanilla beans
# 28970                                         Love this!
# 12603                                    Excellent taste
# 19643                      Mrs. Dash Tomato Basil Garlic
# 16845                                 Our pantry staple!
# 10048                      My favorite and only  MUSTARD
# 16642                  The BEST fig spread on the market
# 25593                                VERY HAPPY CUSTOMER
# 21198                             fine for 13 y.o. doggy
#
#                                                     Text  \
# 0      this witty little book makes my son laugh at l...
# 30     I can remember seeing the show when it aired o...
# 424    Beetlejuice is a well written movie ..... ever...
# 330    A twist of rumplestiskin captured on film, sta...
# 423    Beetlejuice is an excellent and funny movie. K...
# 245    THIS IS ONE MOVIE THAT SHOULD BE IN YOUR MOVIE...
# 308    I, myself always enjoyed this movie, it's very...
# 215    I bought a few of these after my apartment was...
# 261    What happens when you say his name three times...
# 325    I'm getting crazy.I'm looking for Beatlejuice ...
# 427    I'm getting crazy.<p>Is it really impossible t...
# 241    This was a really good idea and the final prod...
# 242    I just received my shipment and could hardly w...
# 485    I have just recently purchased the Woodstream ...
# 868    These are easy to use, they do not make a mess...
# 837    This are so much easier to use than the Wilson...
# 249    This is such a great film, I don't even know h...
# 296    Beetlejuice is an awe-inspiring wonderfully am...
# 844    I'm sick of scads of nasty toothpicks all over...
# 360    I THOUGHT THIS MOVIE WAS SO FUNNY, MICHAEL KEA...
# 329    Many movies, have dealt with the figure of dea...
# 845    I don't know why anyone would ever use those l...
# 425    Michael Keaton brings no distinguishing charac...
# 342    I am continually amazed at the shoddy treatmen...
# 270    Just to warn you. when in trying to trick you ...
# 855    I bought these to decorate some dia de los mue...
# 353    Winona Ryder is HOT! HOT! HOT! as the gothic d...
# 32     This was a favorite book of mine when I was a ...
# 998    For years I have been trying to simulate a tru...
# 331    When vacationing Adam and Barbara Maitland mee...
# ...                                                  ...
# 9663   This product is very good and I won't change i...
# 19228  I was a Tony Chachere's fan for a long time, s...
# 11605  This is a fantastic do-it-yourself poke produc...
# 21309  My dog will come in from outside when I am tra...
# 941    I got these to give out in a goodie bag for th...
# 8351   Ordered these as part of a presentation on Mal...
# 42329  I hardly ever write reviews, this rice is so g...
# 42331  Hard to find in the grocery. I buy it by the c...
# 25099  It was tasty and fresh. The other one I bought...
# 585    no instructions provided. Trap would not open....
# 11521  Very good product, helps with a lot of ailment...
# 586    A very well built mole trap that works great w...
# 54086  I have always bought my pure vanilla extract i...
# 23149  This Salmon Is The Best!  I Try To Make A Smal...
# 50325  I love this French Vanilla tea and it's not av...
# 72818  All my dogs love them. Healthy treats. Not gre...
# 50322  Lipton makes the BEST French Vanilla tea...I h...
# 72236  This product is great - looks, cooking time an...
# 15226  Puppy didn't care for this. Older dog chews on...
# 1637   The only reason I am giving it 4 stars instead...
# 23864  First off, read the ingredients, no crazy word...
# 36415  These are plump, juicy vanilla beans! Perfect ...
# 28970  The pods are easy to use and have a wonderful ...
# 12603  This is to me a great coffee, once you try it ...
# 19643  I saw this advertised in a magazine and was un...
# 16845  I first tried these last year and absolutely f...
# 10048  You've just got to experience this mustard... ...
# 16642  This is my go to spread when I serve a cheese ...
# 25593  If you like sponge candy- and have never tried...
# 21198  My Am Staff is about 13 years old and is a ver...
#
#                                              CleanedText
# 0      witti littl book make son laugh loud recit car...
# 30     rememb see show air televis year ago child sis...
# 424    beetlejuic well written movi everyth excel act...
# 330    twist rumplestiskin captur film star michael k...
# 423    beetlejuic excel funni movi keaton hilari wack...
# 245    one movi movi collect fill comedi action whate...
# 308    alway enjoy movi funni entertain didnt hesit p...
# 215    bought apart infest fruit fli hour trap mani f...
# 261    happen say name three time michael keaten star...
# 325    get crazi look beatlejuic french version video...
# 427    get crazi realli imposs today find french vhs ...
# 241    realli good idea final product outstand use de...
# 242    receiv shipment could hard wait tri product lo...
# 485    recent purchas woodstream corp gopher trap wit...
# 868    easi use make mess offer vibrant color taint d...
# 837    much easier use wilson past color color vibran...
# 249    great film dont even know sum first complet or...
# 296    beetlejuic wonder amus comed romp explor incre...
# 844    sick scad nasti toothpick counter tint concept...
# 360    thought movi funni michael keaton beetlejuic r...
# 329    mani movi dealt figur death dead good angel cl...
# 845    dont know anyon would ever use littl liquid fo...
# 425    michael keaton bring distinguish characterist ...
# 342    continu amaz shoddi treatment movi get dvd rel...
# 270    warn tri trick widescreen format compani made ...
# 855    bought decor dia los muerto skull ice ateco fo...
# 353    winona ryder hot hot hot gothic princess doom ...
# 32     favorit book mine littl girl would read time m...
# 998    year tri simul truli italian espresso cappucci...
# 331    vacat adam barbara maitland meet demis kill lo...
# ...                                                  ...
# 9663   product good wont chang brand vendor made chip...
# 19228  toni chacher fan long time wasnt sway someon c...
# 11605  fantast poke product add sesam oil green onion...
# 21309  dog come outsid train look cupboard wait treat...
# 941    got give goodi bag holiday coupl extra cours a...
# 8351   order part present malaysia fruit left posit i...
# 42329  hard ever write review rice good write live ha...
# 42331  hard find groceri buy case onlin one box make ...
# 25099     tasti fresh one bought old tast moldi one good
# 585    instruct provid trap would open tri set trap c...
# 11521  good product help lot ailment great help stock...
# 586    well built mole trap work great set correct sa...
# 54086  alway bought pure vanilla extract mexico got t...
# 23149  salmon best tri make small varieti salmon dish...
# 50325  love french vanilla tea avail store longer thr...
# 72818  dog love healthi treat great train crumbl tri ...
# 50322  lipton make best french vanilla tea tri other ...
# 72236  product great look cook time tast use year wif...
# 15226  puppi didnt care older dog chew sure much get ...
# 1637   reason give star instead star strang design su...
# 23864  first read ingredi crazi word cant pronounc me...
# 36415  plump juici vanilla bean perfect ice cream mak...
# 28970  pod easi use wonder aroma releas foil packet c...
# 12603            great coffe tri enjoy coffe wonder tast
# 19643  saw advertis magazin unabl find local lucki lo...
# 16845  first tri last year absolut fell love fresh mu...
# 10048  youv got experi mustard queen mother mustard w...
# 16642  spread serv chees platter goe well soft chees ...
# 25593  like spong never tri realli miss abl obtain pr...
# 21198  staff year old dog seem like version eukanuba ...
# [80000 rows x 12 columns]

# %%
print (final.shape)
# Out:
# (80000, 12)

# %%
print(final['CleanedText'].values)
# Out:
# ['witti littl book make son laugh loud recit car drive along alway sing refrain hes learn whale india droop love new word book introduc silli classic book will bet son still abl recit memori colleg'
#  'grew read sendak book watch realli rosi movi incorpor love son love howev miss hard cover version paperback seem kind flimsi take two hand keep page open'
#  'fun way children learn month year learn poem throughout school year like handmot invent poem'
#  ...
#  'found small can local kroger like small much better deal tasti snack'
#  'love snack tasti also qualiti realli good get yummi snack'
#  'asian rice cracker mix basic one greater varieti cracker also quit bit larger use one size big gumbal perhap reason instead packag bag cracker simpli burst flavor scare eat whole singl sit']

# %%
#Using BOW to vectorize

trainX_data=final['CleanedText'].values[0:51200]
testX_data= final['CleanedText'].values[64000:]
cvX_data=final['CleanedText'].values[51200:64000]
trainY_data=final['Score'].values[0:51200]
testY_data=final['Score'].values[64000:]
cvY_data=final['Score'].values[51200:64000]

#Vectorising train data
count_vect = CountVectorizer()
final_counts_train = count_vect.fit_transform(trainX_data)
feature=count_vect.get_feature_names()
#Reducing dimensions of a sparse matrix usind Truncated SVD
svd = TruncatedSVD(n_components=300, n_iter=10, random_state=42)
final_counts_train=svd.fit_transform(final_counts_train)

#print(svd.explained_variance_ratio_)
features=np.arange(1, 301, 1)
#print(features)
Variance_explained=svd.explained_variance_ratio_
cnt=0.0
total_variance=[]
for i in (Variance_explained):
    cnt=cnt+i
    total_variance.append(cnt)

plt.figure()
plt.title("Variance explained per components")
plt.plot(features,total_variance)
plt.xlabel("Number of Components")
plt.ylabel("Total Variance Explained")
plt.show()

with open('BOWfinal_feature_names.pkl', 'wb') as f:
    pickle.dump(feature, f)

with open('BOWfinal_traindata_counts_Further_Use.pkl', 'wb') as f:
    pickle.dump(final_counts_train, f)
    
#Vectorising cross validation data
final_counts_cv=count_vect.transform(cvX_data)
final_counts_cv=svd.fit_transform(final_counts_cv)
#Vectorising test data
final_counts_test=count_vect.transform(testX_data)
final_counts_test=svd.fit_transform(final_counts_test)

# %%
X_train=final_counts_train
X_test =final_counts_test
X_cv=final_counts_cv
y_train=trainY_data
y_test=testY_data
y_cv=cvY_data

# %%
#Saving all the data for further use
with open('BOWfinal_Train_X.pkl', 'wb') as f:
    pickle.dump(X_train, f)
with open('BOWfinal_Train_Y.pkl', 'wb') as f:
    pickle.dump(y_train, f)
with open('BOWfinal_CV_X.pkl', 'wb') as f:
    pickle.dump(X_cv, f)
with open('BOWfinal_CV_Y.pkl', 'wb') as f:
    pickle.dump(y_cv, f)
with open('BOWfinal_Test_X.pkl', 'wb') as f:
    pickle.dump(X_test, f)
with open('BOWfinal_Test_Y.pkl', 'wb') as f:
    pickle.dump(y_test, f)

# %%
# %matplotlib inline

#print(X_train.shape)
accuracy=0.0
neigh=1
f1score=0.0
kvalues=[]
error=[]
#Finding best parameters using Simple Cross Validation
for i in range(1,30,2):
    # instantiate learning model (k = 30)
    knn = KNeighborsClassifier(n_neighbors=i,algorithm='brute')

    # fitting the model on crossvalidation train
    knn.fit(X_train, y_train)

    # predict the response on the crossvalidation train
    pred = knn.predict(X_cv)

    # evaluate CV accuracy
    accur = accuracy_score(y_cv, pred, normalize=True)
    acc = accuracy_score(y_cv, pred, normalize=True) * float(100)
    print('\nCV accuracy for k = %d is %d%%' % (i, acc))
    f1=f1_score(y_cv, pred, average='binary',pos_label='positive')
    print('\nCV f1_score for k = %d is %.10f' % (i, f1))
    err=1-accur
    print("Error value : %.5f"%(err))
    error.append(err)
    kvalues.append(i)
    #if (accuracy<=acc):
    #   accuracy=acc
    #    neigh=i
    #else:
    #    pass
    if (f1score<=f1):
        f1score=f1
        neigh=i
    else:
        pass
plt.plot(kvalues,error)
plt.title("Error Graph")
plt.xlabel('K values')
plt.ylabel('Error')
plt.show()
print("The most optimal value of k is %d" %(neigh))
knn = KNeighborsClassifier(n_neighbors=neigh,algorithm='brute')
knn.fit(X_train,y_train)
pred = knn.predict(X_test)
acc = accuracy_score(y_test, pred, normalize=True) * float(100)
print('\n****Test accuracy for k = %d is %d%%' % (neigh,acc))
f1=f1_score(y_test, pred,average='binary',pos_label='positive')
print('\n Test f1_score for k = %d is %.10f' % (neigh, f1))
cm=confusion_matrix(y_test,pred)
df_cm = pd.DataFrame(cm,index=["negative","positive"],columns=["negative","positive"])
plt.figure()
plt.title("Confusion matrix")
sns.heatmap(df_cm, annot=True,fmt="d")
# Out:
# CV accuracy for k = 1 is 75%
#
# CV f1_score for k = 1 is 0.8572473374
# Error value : 0.24398
#
# CV accuracy for k = 3 is 80%
#
# CV f1_score for k = 3 is 0.8898379711
# Error value : 0.19547
#
# CV accuracy for k = 5 is 82%
#
# CV f1_score for k = 5 is 0.9023872449
# Error value : 0.17602
#
# CV accuracy for k = 7 is 83%
#
# CV f1_score for k = 7 is 0.9092703863
# Error value : 0.16516
#
# CV accuracy for k = 9 is 84%
#
# CV f1_score for k = 9 is 0.9137055838
# Error value : 0.15805
#
# CV accuracy for k = 11 is 84%
#
# CV f1_score for k = 11 is 0.9155755824
# Error value : 0.15516
#
# CV accuracy for k = 13 is 84%
#
# CV f1_score for k = 13 is 0.9174086322
# Error value : 0.15219
#
# CV accuracy for k = 15 is 84%
#
# CV f1_score for k = 15 is 0.9184451220
# Error value : 0.15047
#
# CV accuracy for k = 17 is 85%
#
# CV f1_score for k = 17 is 0.9197919750
# Error value : 0.14820
#
# CV accuracy for k = 19 is 85%
#
# CV f1_score for k = 19 is 0.9202552508
# Error value : 0.14742
#
# CV accuracy for k = 21 is 85%
#
# CV f1_score for k = 21 is 0.9206282192
# Error value : 0.14687
#
# CV accuracy for k = 23 is 85%
#
# CV f1_score for k = 23 is 0.9212791090
# Error value : 0.14578
#
# CV accuracy for k = 25 is 85%
#
# CV f1_score for k = 25 is 0.9219224283
# Error value : 0.14469
#
# CV accuracy for k = 27 is 85%
#
# CV f1_score for k = 27 is 0.9220653319
# Error value : 0.14445
#
# CV accuracy for k = 29 is 85%
#
# CV f1_score for k = 29 is 0.9220916024
# Error value : 0.14445
# The most optimal value of k is 29
#
# ****Test accuracy for k = 29 is 86%
#
#  Test f1_score for k = 29 is 0.9273544406

# %%
#creating the model with BOW and KDD KNN
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
print("Running KNN using KD Tree on BOW ")

accuracy=0.0
neigh=1
f1score=0.0
kvalues=[]
error=[]
#Finding best parameters using Simple Cross Validation
for i in range(1,30,2):
    # instantiate learning model (k = 30)
    knn = KNeighborsClassifier(n_neighbors=i,algorithm='kd_tree')

    # fitting the model on crossvalidation train
    knn.fit(X_train, y_train)

    # predict the response on the crossvalidation train
    pred = knn.predict(X_cv)

    # evaluate CV accuracy
    accur = accuracy_score(y_cv, pred, normalize=True)
    acc = accuracy_score(y_cv, pred, normalize=True) * float(100)
    print('\nCV accuracy for k = %d is %d%%' % (i, acc))
    f1=f1_score(y_cv, pred, average='binary',pos_label='positive')
    print('\nCV f1_score for k = %d is %.10f' % (i, f1))
    err=1-accur
    print("Error value : %.5f"%(err))
    error.append(err)
    kvalues.append(i)
    #if (accuracy<=acc):
    #   accuracy=acc
    #    neigh=i
    #else:
    #    pass
    if (f1score<=f1):
        f1score=f1
        neigh=i
    else:
        pass
plt.plot(kvalues,error)
plt.title("Error Graph")
plt.xlabel('K values')
plt.ylabel('Error')
plt.show()
print("The most optimal value of k is %d" %(neigh))
knn = KNeighborsClassifier(n_neighbors=neigh,algorithm='kd_tree')
knn.fit(X_train,y_train)
pred = knn.predict(X_test)
acc = accuracy_score(y_test, pred, normalize=True) * float(100)
print('\n****Test accuracy for k = %d is %d%%' % (neigh,acc))
f1=f1_score(y_test, pred,average='binary',pos_label='positive')
print('\n Test f1_score for k = %d is %.10f' % (neigh, f1))
cm=confusion_matrix(y_test,pred)
df_cm = pd.DataFrame(cm,index=["negative","positive"],columns=["negative","positive"])
plt.figure()
plt.title("Confusion matrix")
sns.heatmap(df_cm, annot=True,fmt="d")
# Out:
# Running KNN using KD Tree on BOW
#
# CV accuracy for k = 1 is 75%
#
# CV f1_score for k = 1 is 0.8572473374
# Error value : 0.24398
#
# CV accuracy for k = 3 is 80%
#
# CV f1_score for k = 3 is 0.8898379711
# Error value : 0.19547
#
# CV accuracy for k = 5 is 82%
#
# CV f1_score for k = 5 is 0.9023872449
# Error value : 0.17602
#
# CV accuracy for k = 7 is 83%
#
# CV f1_score for k = 7 is 0.9092703863
# Error value : 0.16516
#
# CV accuracy for k = 9 is 84%
#
# CV f1_score for k = 9 is 0.9137055838
# Error value : 0.15805
#
# CV accuracy for k = 11 is 84%
#
# CV f1_score for k = 11 is 0.9155755824
# Error value : 0.15516
#
# CV accuracy for k = 13 is 84%
#
# CV f1_score for k = 13 is 0.9174086322
# Error value : 0.15219
#
# CV accuracy for k = 15 is 84%
#
# CV f1_score for k = 15 is 0.9184451220
# Error value : 0.15047
#
# CV accuracy for k = 17 is 85%
#
# CV f1_score for k = 17 is 0.9197919750
# Error value : 0.14820
#
# CV accuracy for k = 19 is 85%
#
# CV f1_score for k = 19 is 0.9202552508
# Error value : 0.14742
#
# CV accuracy for k = 21 is 85%
#
# CV f1_score for k = 21 is 0.9206282192
# Error value : 0.14687
#
# CV accuracy for k = 23 is 85%
#
# CV f1_score for k = 23 is 0.9212791090
# Error value : 0.14578
#
# CV accuracy for k = 25 is 85%
#
# CV f1_score for k = 25 is 0.9219224283
# Error value : 0.14469
#
# CV accuracy for k = 27 is 85%
#
# CV f1_score for k = 27 is 0.9220653319
# Error value : 0.14445
#
# CV accuracy for k = 29 is 85%
#
# CV f1_score for k = 29 is 0.9220916024
# Error value : 0.14445
# The most optimal value of k is 29
#
# ****Test accuracy for k = 29 is 86%
#
#  Test f1_score for k = 29 is 0.9273544406

# %%
import warnings
warnings.filterwarnings("ignore")
#Vectorizing using TFIDF
#TF IDF Vectorizing


trainX_data=final['CleanedText'].values[0:46400]
testX_data= final['CleanedText'].values[58000:70000]
cvX_data=final['CleanedText'].values[46400:58000]
trainY_data=final['Score'].values[0:46400]
testY_data=final['Score'].values[58000:70000]
cvY_data=final['Score'].values[46400:58000]


tf_idf_vect = TfidfVectorizer(max_features=2000,min_df=50)
final_tf_idf_train = tf_idf_vect.fit_transform(trainX_data)
#Reducing dimensions of a sparse matrix usind Truncated SVD
svd = TruncatedSVD(n_components=300, n_iter=10, random_state=42)
final_tf_idf_train=svd.fit_transform(final_tf_idf_train)

#print(svd.explained_variance_ratio_)
features=np.arange(1, 301, 1)
#print(features)
Variance_explained=svd.explained_variance_ratio_
cnt=0.0
total_variance=[]
for i in (Variance_explained):
    cnt=cnt+i
    total_variance.append(cnt)

plt.figure()
plt.title("Variance explained per components")
plt.plot(features,total_variance)
plt.xlabel("Number of Components")
plt.ylabel("Total Variance Explained")
plt.show()


feature=tf_idf_vect.get_feature_names()

with open('TFIDFfinal_feature_names.pkl', 'wb') as f:
    pickle.dump(feature, f)
    
final_tf_idf_test=tf_idf_vect.transform(testX_data)
final_tf_idf_test=svd.transform(final_tf_idf_test)
 

final_tf_idf_cv=tf_idf_vect.transform(cvX_data)
final_tf_idf_cv=svd.transform(final_tf_idf_cv)

# %%
import warnings
warnings.filterwarnings("ignore")
X_train=final_tf_idf_train
X_test =final_tf_idf_test
X_cv=final_tf_idf_cv
y_train=trainY_data
y_test=testY_data
y_cv=cvY_data

# %%
import warnings
warnings.filterwarnings("ignore")
#creating the model with TFIDF and brute force KNN

#Saving all the data for further use
with open('TFIDFfinal_Train_X.pkl', 'wb') as f:
    pickle.dump(X_train, f)
with open('TFIDFfinal_Train_Y.pkl', 'wb') as f:
    pickle.dump(y_train, f)
with open('TFIDFfinal_CV_X.pkl', 'wb') as f:
    pickle.dump(X_cv, f)
with open('TFIDFfinal_CV_Y.pkl', 'wb') as f:
    pickle.dump(y_cv, f)
with open('TFIDFfinal_Test_X.pkl', 'wb') as f:
    pickle.dump(X_test, f)
with open('TFIDFfinal_Test_Y.pkl', 'wb') as f:
    pickle.dump(y_test, f)

# %%
import warnings
warnings.filterwarnings("ignore")

print("Running KNN using Brute Force on TFIDF Vectorized data")

accuracy=0.0
neigh=1
f1score=0.0
kvalues=[]
error=[]
#Finding best parameters using Simple Cross Validation
for i in range(1,30,2):
    # instantiate learning model (k = 30)
    knn = KNeighborsClassifier(n_neighbors=i,algorithm='brute')

    # fitting the model on crossvalidation train
    knn.fit(X_train, y_train)

    # predict the response on the crossvalidation train
    pred = knn.predict(X_cv)

    # evaluate CV accuracy
    accu=accuracy_score(y_cv, pred, normalize=True)
    acc = accuracy_score(y_cv, pred, normalize=True) * float(100)
    print('\nCV accuracy for k = %d is %d%%' % (i, acc))
    f1=f1_score(y_cv, pred, average='binary',pos_label='positive')
    print('\nCV f1_score for k = %d is %.10f' % (i, f1))
    #calculating error
    err=1-accu
    print("Error value : %.5f"%(err))
    error.append(err)
    kvalues.append(i)
    
    if (f1score<=f1):
        f1score=f1
        neigh=i
    else:
        pass

plt.figure()
plt.plot(kvalues,error)
plt.title("Error Graph")
plt.xlabel('K values')
plt.ylabel('Error')
plt.show()   
print ("The optimal value of k is %d"%(neigh))   
knn = KNeighborsClassifier(n_neighbors=neigh,algorithm='brute')
knn.fit(X_train,y_train)
pred = knn.predict(X_test)
acc = accuracy_score(y_test, pred, normalize=True) * float(100)
print('\n****Test accuracy for k = %d is %d%%' % (neigh,acc))
f1=f1_score(y_test, pred,average='binary',pos_label='positive')
print('\n Test f1_score for k = %d is %.10f' % (neigh, f1))
cm=confusion_matrix(y_test,pred)
df_cm = pd.DataFrame(cm,index=["negative","positive"],columns=["negative","positive"])
plt.figure()
plt.title("Confusion matrix")
sns.heatmap(df_cm, annot=True,fmt="d")
# Out:
# Running KNN using Brute Force on TFIDF Vectorized data
#
# CV accuracy for k = 1 is 75%
#
# CV f1_score for k = 1 is 0.8522477208
# Error value : 0.24310
#
# CV accuracy for k = 3 is 81%
#
# CV f1_score for k = 3 is 0.8942365419
# Error value : 0.18224
#
# CV accuracy for k = 5 is 84%
#
# CV f1_score for k = 5 is 0.9097586055
# Error value : 0.15888
#
# CV accuracy for k = 7 is 84%
#
# CV f1_score for k = 7 is 0.9155555556
# Error value : 0.15069
#
# CV accuracy for k = 9 is 85%
#
# CV f1_score for k = 9 is 0.9189862502
# Error value : 0.14578
#
# CV accuracy for k = 11 is 85%
#
# CV f1_score for k = 11 is 0.9217656302
# Error value : 0.14164
#
# CV accuracy for k = 13 is 86%
#
# CV f1_score for k = 13 is 0.9248576850
# Error value : 0.13655
#
# CV accuracy for k = 15 is 86%
#
# CV f1_score for k = 15 is 0.9256775900
# Error value : 0.13569
#
# CV accuracy for k = 17 is 86%
#
# CV f1_score for k = 17 is 0.9258613376
# Error value : 0.13560
#
# CV accuracy for k = 19 is 86%
#
# CV f1_score for k = 19 is 0.9258562288
# Error value : 0.13586
#
# CV accuracy for k = 21 is 86%
#
# CV f1_score for k = 21 is 0.9261852182
# Error value : 0.13543
#
# CV accuracy for k = 23 is 86%
#
# CV f1_score for k = 23 is 0.9268429938
# Error value : 0.13448
#
# CV accuracy for k = 25 is 86%
#
# CV f1_score for k = 25 is 0.9274167096
# Error value : 0.13353
#
# CV accuracy for k = 27 is 86%
#
# CV f1_score for k = 27 is 0.9278562740
# Error value : 0.13293
#
# CV accuracy for k = 29 is 86%
#
# CV f1_score for k = 29 is 0.9279034973
# Error value : 0.13293
# The optimal value of k is 29
#
# ****Test accuracy for k = 29 is 85%
#
#  Test f1_score for k = 29 is 0.9224337711

# %%
import warnings
warnings.filterwarnings("ignore")
print("Running KNN using KD Tree on TFIDF Vectorized data")

accuracy=0.0
neigh=1
f1score=0.0
kvalues=[]
error=[]
#Finding best parameters using Simple Cross Validation
for i in range(1,30,2):
    # instantiate learning model (k = 30)
    knn = KNeighborsClassifier(n_neighbors=i,algorithm='kd_tree')

    # fitting the model on crossvalidation train
    knn.fit(X_train, y_train)

    # predict the response on the crossvalidation train
    pred = knn.predict(X_cv)

    # evaluate CV accuracy
    accu=accuracy_score(y_cv, pred, normalize=True)
    acc = accuracy_score(y_cv, pred, normalize=True) * float(100)
    print('\nCV accuracy for k = %d is %d%%' % (i, acc))
    f1=f1_score(y_cv, pred, average='binary',pos_label='positive')
    print('\nCV f1_score for k = %d is %.10f' % (i, f1))
    #calculating error
    err=1-accu
    print("Error value : %.5f"%(err))
    error.append(err)
    kvalues.append(i)
    
    if (f1score<=f1):
        f1score=f1
        neigh=i
    else:
        pass

plt.figure()
plt.plot(kvalues,error)
plt.title("Error Graph")
plt.xlabel('K values')
plt.ylabel('Error')
plt.show()   
print ("The optimal value of k is %d"%(neigh))   
knn = KNeighborsClassifier(n_neighbors=neigh,algorithm='kd_tree')
knn.fit(X_train,y_train)
pred = knn.predict(X_test)
acc = accuracy_score(y_test, pred, normalize=True) * float(100)
print('\n****Test accuracy for k = %d is %d%%' % (neigh,acc))
f1=f1_score(y_test, pred,average='binary',pos_label='positive')
print('\n Test f1_score for k = %d is %.10f' % (neigh, f1))
cm=confusion_matrix(y_test,pred)
df_cm = pd.DataFrame(cm,index=["negative","positive"],columns=["negative","positive"])
plt.figure()
plt.title("Confusion matrix")
sns.heatmap(df_cm, annot=True,fmt="d")
# Out:
# Running KNN using KD Tree on TFIDF Vectorized data
#
# CV accuracy for k = 1 is 75%
#
# CV f1_score for k = 1 is 0.8475612971
# Error value : 0.24922
#
# CV accuracy for k = 3 is 81%
#
# CV f1_score for k = 3 is 0.8908204793
# Error value : 0.18733
#
# CV accuracy for k = 5 is 83%
#
# CV f1_score for k = 5 is 0.9084396467
# Error value : 0.16086
#
# CV accuracy for k = 7 is 84%
#
# CV f1_score for k = 7 is 0.9147721776
# Error value : 0.15190
#
# CV accuracy for k = 9 is 85%
#
# CV f1_score for k = 9 is 0.9185092810
# Error value : 0.14647
#
# CV accuracy for k = 11 is 85%
#
# CV f1_score for k = 11 is 0.9214425230
# Error value : 0.14216
#
# CV accuracy for k = 13 is 86%
#
# CV f1_score for k = 13 is 0.9247781311
# Error value : 0.13664
#
# CV accuracy for k = 15 is 86%
#
# CV f1_score for k = 15 is 0.9258664652
# Error value : 0.13534
#
# CV accuracy for k = 17 is 86%
#
# CV f1_score for k = 17 is 0.9258473578
# Error value : 0.13560
#
# CV accuracy for k = 19 is 86%
#
# CV f1_score for k = 19 is 0.9260513689
# Error value : 0.13552
#
# CV accuracy for k = 21 is 86%
#
# CV f1_score for k = 21 is 0.9261347618
# Error value : 0.13552
#
# CV accuracy for k = 23 is 86%
#
# CV f1_score for k = 23 is 0.9268361317
# Error value : 0.13448
#
# CV accuracy for k = 25 is 86%
#
# CV f1_score for k = 25 is 0.9274601687
# Error value : 0.13345
#
# CV accuracy for k = 27 is 86%
#
# CV f1_score for k = 27 is 0.9278562740
# Error value : 0.13293
#
# CV accuracy for k = 29 is 86%
#
# CV f1_score for k = 29 is 0.9279468836
# Error value : 0.13284
# The optimal value of k is 29
#
# ****Test accuracy for k = 29 is 85%
#
#  Test f1_score for k = 29 is 0.9224337711

# %%
import warnings
warnings.filterwarnings("ignore")
#Creating W2V model
#WORD TO VECTOR
datawtovtrain = final['CleanedText'].values[0:51200]

i=0
list_of_sent=[]
for sent in datawtovtrain:
    list_of_sent.append(sent.split())
w2v_model=Word2Vec(list_of_sent,min_count=5,size=50, workers=4)
w2v_words = list(w2v_model.wv.vocab)
print("number of words that occured minimum 5 times ",len(w2v_words))
print("sample words ", w2v_words[0:50])

sent_vectors_train = []; 
for sent in tqdm(list_of_sent): # for each review/sentence
    sent_vec = np.zeros(50) # as word vectors are of zero length
    for word in sent: # for each word in a review/sentence
        if word in w2v_words:
            vec = w2v_model.wv[word]
            sent_vec += vec
    sent_vectors_train.append(sent_vec)
print(len(sent_vectors_train))
W2VScoretrain=final['Score'].values[0:51200]
# Out:
# number of words that occured minimum 5 times  9691
# sample words  ['littl', 'book', 'make', 'son', 'laugh', 'loud', 'recit', 'car', 'drive', 'along', 'alway', 'sing', 'refrain', 'hes', 'learn', 'whale', 'india', 'droop', 'love', 'new', 'word', 'introduc', 'silli', 'classic', 'will', 'bet', 'still', 'abl', 'memori', 'colleg', 'grew', 'read', 'sendak', 'watch', 'realli', 'rosi', 'movi', 'incorpor', 'howev', 'miss', 'hard', 'cover', 'version', 'paperback', 'seem', 'kind', 'flimsi', 'take', 'two', 'hand']
# 100%|███████████████████████████████████████████████████████████████████████████| 51200/51200 [00:53<00:00, 963.00it/s]
# 51200

# %%
import warnings
warnings.filterwarnings("ignore")
#Creating W2V model
#WORD TO VECTOR
datawtovcv = final['CleanedText'].values[51200:64000]

i=0
list_of_sent=[]
for sent in datawtovcv:
    list_of_sent.append(sent.split())
w2v_model=Word2Vec(list_of_sent,min_count=5,size=50, workers=4)
w2v_words = list(w2v_model.wv.vocab)
print("number of words that occured minimum 5 times ",len(w2v_words))
print("sample words ", w2v_words[0:50])

sent_vectors_cv = []; 
for sent in tqdm(list_of_sent): # for each review/sentence
    sent_vec = np.zeros(50) # as word vectors are of zero length
    for word in sent: # for each word in a review/sentence
        if word in w2v_words:
            vec = w2v_model.wv[word]
            sent_vec += vec
    sent_vectors_cv.append(sent_vec)
print(len(sent_vectors_cv))
W2VScorecv=final['Score'].values[51200:64000]
# Out:
# number of words that occured minimum 5 times  4496
# sample words  ['best', 'granola', 'bar', 'ever', 'plus', 'got', 'sale', 'made', 'even', 'better', 'get', 'children', 'eat', 'littl', 'bit', 'fiber', 'realli', 'good', 'cours', 'almond', 'mix', 'nut', 'flavor', 'would', 'give', 'five', 'star', 'found', 'like', 'roast', 'peanut', 'fantast', 'snack', 'sweet', 'crunchi', 'chewi', 'nutti', 'salti', 'usual', 'hate', 'love', 'fan', 'tri', 'recent', 'one', 'breakfast', 'minut', 'ago', 'matter', 'fact']
# 100%|██████████████████████████████████████████████████████████████████████████| 12800/12800 [00:07<00:00, 1662.35it/s]
# 12800

# %%
import warnings
warnings.filterwarnings("ignore")
#Creating W2V model
#WORD TO VECTOR
datawtovtest = final['CleanedText'].values[64000:]


i=0
list_of_sent=[]
for sent in datawtovtest:
    list_of_sent.append(sent.split())
w2v_model=Word2Vec(list_of_sent,min_count=5,size=50, workers=4)
w2v_words = list(w2v_model.wv.vocab)
print("number of words that occured minimum 5 times ",len(w2v_words))
print("sample words ", w2v_words[0:50])

sent_vectors_test = []; 
for sent in tqdm(list_of_sent): # for each review/sentence
    sent_vec = np.zeros(50) # as word vectors are of zero length
    for word in sent: # for each word in a review/sentence
        if word in w2v_words:
            vec = w2v_model.wv[word]
            sent_vec += vec
    sent_vectors_test.append(sent_vec)
print(len(sent_vectors_test))
W2VScoretest=final['Score'].values[64000:]
# Out:
# number of words that occured minimum 5 times  4917
# sample words  ['tortellini', 'dri', 'graini', 'come', 'small', 'box', 'couldnt', 'eat', 'flavor', 'strong', 'good', 'end', 'donat', 'remain', 'bought', 'time', 'ago', 'amazon', 'back', 'davinci', 'tri', 'barilla', 'brand', 'find', 'quit', 'tasti', 'lack', 'filler', 'use', 'great', 'butter', 'grate', 'chees', 'various', 'sauc', 'make', 'yummi', 'italian', 'salad', 'cut', 'hard', 'salami', 'chunk', 'pickl', 'veggi', 'marin', 'artichok', 'oliv', 'love', 'eas']
# 100%|██████████████████████████████████████████████████████████████████████████| 16000/16000 [00:09<00:00, 1655.54it/s]
# 16000

# %%
import warnings
warnings.filterwarnings("ignore")

#Train Test Split of W2V data
#creating the model with W2V and brute force KNN
X_train = sent_vectors_train
X_cv=sent_vectors_cv
X_test = sent_vectors_test
Y_train = W2VScoretrain
Y_cv = W2VScorecv
Y_test = W2VScoretest

# %%
#Saving all the data for further use
with open('W2Vfinal_Train_X.pkl', 'wb') as f:
    pickle.dump(X_train, f)
with open('W2Vfinal_Train_Y.pkl', 'wb') as f:
    pickle.dump(Y_train, f)
with open('W2Vfinal_CV_X.pkl', 'wb') as f:
    pickle.dump(X_cv, f)
with open('W2Vfinal_CV_Y.pkl', 'wb') as f:
    pickle.dump(Y_cv, f)
with open('W2Vfinal_Test_X.pkl', 'wb') as f:
    pickle.dump(X_test, f)
with open('W2Vfinal_Test_Y.pkl', 'wb') as f:
    pickle.dump(Y_test, f)

# %%
import warnings
warnings.filterwarnings("ignore")
#Brute Force KNN on W2V
print("Running KNN using Brute Force on W2V Vectorized data")
accuracy=0.0
neigh=1
f1score=0.0
kvalues=[]
error=[]
#Finding best parameters using Simple Cross Validation
for i in range(1,30,2):
    # instantiate learning model (k = 30)
    knn = KNeighborsClassifier(n_neighbors=i,algorithm='brute')

    # fitting the model on crossvalidation train
    knn.fit(X_train, Y_train)

    # predict the response on the crossvalidation train
    pred = knn.predict(X_cv)

    # evaluate CV accuracy
    accu=accuracy_score(Y_cv, pred, normalize=True)
    acc = accuracy_score(Y_cv, pred, normalize=True) * float(100)
    print('\nCV accuracy for k = %d is %d%%' % (i, acc))
    f1=f1_score(Y_cv, pred, average='binary',pos_label='positive')
    print('\nCV f1_score for k = %d is %.10f' % (i, f1))
    #calculating error
    err=1-accu
    print("Error value : %.5f"%(err))
    error.append(err)
    kvalues.append(i)
    
    if (f1score<=f1):
        f1score=f1
        neigh=i
    else:
        pass

plt.figure()
plt.plot(kvalues,error)
plt.title("Error Graph")
plt.xlabel('K values')
plt.ylabel('Error')
plt.show()   
print ("The optimal value of k is %d"%(neigh))   
knn = KNeighborsClassifier(n_neighbors=neigh,algorithm='brute')
knn.fit(X_train,Y_train)
pred = knn.predict(X_test)
acc = accuracy_score(Y_test, pred, normalize=True) * float(100)
print('\n****Test accuracy for k = %d is %d%%' % (neigh,acc))
f1=f1_score(Y_test, pred,average='binary',pos_label='positive')
print('\n Test f1_score for k = %d is %.10f' % (neigh, f1))
cm=confusion_matrix(Y_test,pred)
df_cm = pd.DataFrame(cm,index=["negative","positive"],columns=["negative","positive"])
plt.figure()
plt.title("Confusion matrix")
sns.heatmap(df_cm, annot=True,fmt="d")
# Out:
# Running KNN using Brute Force on W2V Vectorized data
#
# CV accuracy for k = 1 is 74%
#
# CV f1_score for k = 1 is 0.8497830043
# Error value : 0.25148
#
# CV accuracy for k = 3 is 78%
#
# CV f1_score for k = 3 is 0.8782447745
# Error value : 0.21070
#
# CV accuracy for k = 5 is 80%
#
# CV f1_score for k = 5 is 0.8914326279
# Error value : 0.19117
#
# CV accuracy for k = 7 is 82%
#
# CV f1_score for k = 7 is 0.9018818381
# Error value : 0.17516
#
# CV accuracy for k = 9 is 83%
#
# CV f1_score for k = 9 is 0.9066017645
# Error value : 0.16789
#
# CV accuracy for k = 11 is 83%
#
# CV f1_score for k = 11 is 0.9097585209
# Error value : 0.16320
#
# CV accuracy for k = 13 is 84%
#
# CV f1_score for k = 13 is 0.9132639904
# Error value : 0.15766
#
# CV accuracy for k = 15 is 84%
#
# CV f1_score for k = 15 is 0.9145038823
# Error value : 0.15570
#
# CV accuracy for k = 17 is 84%
#
# CV f1_score for k = 17 is 0.9161036518
# Error value : 0.15328
#
# CV accuracy for k = 19 is 84%
#
# CV f1_score for k = 19 is 0.9180565627
# Error value : 0.15008
#
# CV accuracy for k = 21 is 85%
#
# CV f1_score for k = 21 is 0.9194873760
# Error value : 0.14773
#
# CV accuracy for k = 23 is 85%
#
# CV f1_score for k = 23 is 0.9202855443
# Error value : 0.14656
#
# CV accuracy for k = 25 is 85%
#
# CV f1_score for k = 25 is 0.9196553627
# Error value : 0.14789
#
# CV accuracy for k = 27 is 85%
#
# CV f1_score for k = 27 is 0.9204492477
# Error value : 0.14664
#
# CV accuracy for k = 29 is 85%
#
# CV f1_score for k = 29 is 0.9207962728
# Error value : 0.14609
# The optimal value of k is 29
#
# ****Test accuracy for k = 29 is 79%
#
#  Test f1_score for k = 29 is 0.8811294865

# %%
import warnings
warnings.filterwarnings("ignore")
print("Running KNN using KD Tree on W2V Vectorized data")

accuracy=0.0
neigh=1
f1score=0.0
kvalues=[]
error=[]
#Finding best parameters using Simple Cross Validation
for i in range(1,30,2):
    # instantiate learning model (k = 30)
    knn = KNeighborsClassifier(n_neighbors=i,algorithm='kd_tree')

    # fitting the model on crossvalidation train
    knn.fit(X_train, Y_train)

    # predict the response on the crossvalidation train
    pred = knn.predict(X_cv)

    # evaluate CV accuracy
    accu=accuracy_score(Y_cv, pred, normalize=True)
    acc = accuracy_score(Y_cv, pred, normalize=True) * float(100)
    print('\nCV accuracy for k = %d is %d%%' % (i, acc))
    f1=f1_score(Y_cv, pred, average='binary',pos_label='positive')
    print('\nCV f1_score for k = %d is %.10f' % (i, f1))
    #calculating error
    err=1-accu
    print("Error value : %.5f"%(err))
    error.append(err)
    kvalues.append(i)
    
    if (f1score<=f1):
        f1score=f1
        neigh=i
    else:
        pass

plt.figure()
plt.plot(kvalues,error)
plt.title("Error Graph")
plt.xlabel('K values')
plt.ylabel('Error')
plt.show()   
print ("The optimal value of k is %d"%(neigh))   
knn = KNeighborsClassifier(n_neighbors=neigh,algorithm='kd_tree')
knn.fit(X_train,Y_train)
pred = knn.predict(X_test)
acc = accuracy_score(Y_test, pred, normalize=True) * float(100)
print('\n****Test accuracy for k = %d is %d%%' % (neigh,acc))
f1=f1_score(Y_test, pred,average='binary',pos_label='positive')
print('\n Test f1_score for k = %d is %.10f' % (neigh, f1))
cm=confusion_matrix(Y_test,pred)
df_cm = pd.DataFrame(cm,index=["negative","positive"],columns=["negative","positive"])
plt.figure()
plt.title("Confusion matrix")
sns.heatmap(df_cm, annot=True,fmt="d")
# Out:
# Running KNN using KD Tree on W2V Vectorized data
#
# CV accuracy for k = 1 is 74%
#
# CV f1_score for k = 1 is 0.8497830043
# Error value : 0.25148
#
# CV accuracy for k = 3 is 78%
#
# CV f1_score for k = 3 is 0.8782447745
# Error value : 0.21070
#
# CV accuracy for k = 5 is 80%
#
# CV f1_score for k = 5 is 0.8914326279
# Error value : 0.19117
#
# CV accuracy for k = 7 is 82%
#
# CV f1_score for k = 7 is 0.9018818381
# Error value : 0.17516
#
# CV accuracy for k = 9 is 83%
#
# CV f1_score for k = 9 is 0.9066017645
# Error value : 0.16789
#
# CV accuracy for k = 11 is 83%
#
# CV f1_score for k = 11 is 0.9097585209
# Error value : 0.16320
#
# CV accuracy for k = 13 is 84%
#
# CV f1_score for k = 13 is 0.9132639904
# Error value : 0.15766
#
# CV accuracy for k = 15 is 84%
#
# CV f1_score for k = 15 is 0.9145038823
# Error value : 0.15570
#
# CV accuracy for k = 17 is 84%
#
# CV f1_score for k = 17 is 0.9161036518
# Error value : 0.15328
#
# CV accuracy for k = 19 is 84%
#
# CV f1_score for k = 19 is 0.9180565627
# Error value : 0.15008
#
# CV accuracy for k = 21 is 85%
#
# CV f1_score for k = 21 is 0.9194873760
# Error value : 0.14773
#
# CV accuracy for k = 23 is 85%
#
# CV f1_score for k = 23 is 0.9202855443
# Error value : 0.14656
#
# CV accuracy for k = 25 is 85%
#
# CV f1_score for k = 25 is 0.9196553627
# Error value : 0.14789
#
# CV accuracy for k = 27 is 85%
#
# CV f1_score for k = 27 is 0.9204492477
# Error value : 0.14664
#
# CV accuracy for k = 29 is 85%
#
# CV f1_score for k = 29 is 0.9207962728
# Error value : 0.14609
# The optimal value of k is 29
#
# ****Test accuracy for k = 29 is 79%
#
#  Test f1_score for k = 29 is 0.8811294865

# %%
import warnings
warnings.filterwarnings("ignore")
#Creating W2V model
#WORD TO VECTOR
datawtovtrain = final['CleanedText'].values[0:51200]

i=0
list_of_sent=[]
for sent in datawtovtrain:
    list_of_sent.append(sent.split())
w2v_model=Word2Vec(list_of_sent,min_count=5,size=50, workers=4)
w2v_words = list(w2v_model.wv.vocab)
print("number of words that occured minimum 5 times ",len(w2v_words))
print("sample words ", w2v_words[0:50])

sent_vectors_train = []; 
for sent in tqdm(list_of_sent): # for each review/sentence
    sent_vec = np.zeros(50) # as word vectors are of zero length
    for word in sent: # for each word in a review/sentence
        if word in w2v_words:
            vec = w2v_model.wv[word]
            sent_vec += vec
    sent_vectors_train.append(sent_vec)
print(len(sent_vectors_train))
W2VScoretrain=final['Score'].values[0:51200]
# Out:
# number of words that occured minimum 5 times  9691
# sample words  ['littl', 'book', 'make', 'son', 'laugh', 'loud', 'recit', 'car', 'drive', 'along', 'alway', 'sing', 'refrain', 'hes', 'learn', 'whale', 'india', 'droop', 'love', 'new', 'word', 'introduc', 'silli', 'classic', 'will', 'bet', 'still', 'abl', 'memori', 'colleg', 'grew', 'read', 'sendak', 'watch', 'realli', 'rosi', 'movi', 'incorpor', 'howev', 'miss', 'hard', 'cover', 'version', 'paperback', 'seem', 'kind', 'flimsi', 'take', 'two', 'hand']
# 100%|███████████████████████████████████████████████████████████████████████████| 51200/51200 [00:55<00:00, 916.50it/s]
# 51200

# %%
#TFIDF WEIGHTED W2V
import warnings
warnings.filterwarnings("ignore")

datatfidftrain = final['CleanedText'].values[0:51200]

model = TfidfVectorizer()
tf_idf_matrix = model.fit_transform(datatfidftrain)
# we are converting a dictionary with word as a key, and the idf as a value
dictionary = dict(zip(model.get_feature_names(), list(model.idf_)))

# %%
import warnings
warnings.filterwarnings("ignore")
# TF-IDF weighted Word2Vec
tfidf_feat = model.get_feature_names() # tfidf words/col-names


tfidf_sent_vectors_train = []; # the tfidf-w2v for each sentence/review is stored in this list
row=0;
for sent in tqdm(list_of_sent): # for each review/sentence 
    sent_vec = np.zeros(50) # as word vectors are of zero length
    weight_sum =0; # num of words with a valid vector in the sentence/review
    for word in sent: # for each word in a review/sentence
        if word in w2v_words:
            vec = w2v_model.wv[word]

            tf_idf = dictionary[word]*(sent.count(word)/len(sent))
            sent_vec += (vec * tf_idf)
            weight_sum += tf_idf
    if weight_sum != 0:
        sent_vec /= weight_sum
    tfidf_sent_vectors_train.append(sent_vec)
    row += 1
TFIDFW2VScoretrain=final['Score'].values[0:51200]
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 51200/51200 [01:13<00:00, 700.08it/s]

# %%
import warnings
warnings.filterwarnings("ignore")
#Creating W2V model
#WORD TO VECTOR
datawtovcv = final['CleanedText'].values[51200:64000]

i=0
list_of_sent=[]
for sent in datawtovcv:
    list_of_sent.append(sent.split())
w2v_model=Word2Vec(list_of_sent,min_count=5,size=50, workers=4)
w2v_words = list(w2v_model.wv.vocab)
print("number of words that occured minimum 5 times ",len(w2v_words))
print("sample words ", w2v_words[0:50])

sent_vectors_cv = []; 
for sent in tqdm(list_of_sent): # for each review/sentence
    sent_vec = np.zeros(50) # as word vectors are of zero length
    for word in sent: # for each word in a review/sentence
        if word in w2v_words:
            vec = w2v_model.wv[word]
            sent_vec += vec
    sent_vectors_cv.append(sent_vec)
print(len(sent_vectors_cv))
W2VScorecv=final['Score'].values[51200:64000]
# Out:
# number of words that occured minimum 5 times  4496
# sample words  ['best', 'granola', 'bar', 'ever', 'plus', 'got', 'sale', 'made', 'even', 'better', 'get', 'children', 'eat', 'littl', 'bit', 'fiber', 'realli', 'good', 'cours', 'almond', 'mix', 'nut', 'flavor', 'would', 'give', 'five', 'star', 'found', 'like', 'roast', 'peanut', 'fantast', 'snack', 'sweet', 'crunchi', 'chewi', 'nutti', 'salti', 'usual', 'hate', 'love', 'fan', 'tri', 'recent', 'one', 'breakfast', 'minut', 'ago', 'matter', 'fact']
# 100%|██████████████████████████████████████████████████████████████████████████| 12800/12800 [00:07<00:00, 1601.39it/s]
# 12800

# %%
#TFIDF WEIGHTED W2V
import warnings
warnings.filterwarnings("ignore")

datatfidfcv = final['CleanedText'].values[51200:64000]
model = TfidfVectorizer()
tf_idf_matrix = model.fit_transform(datatfidfcv)
# we are converting a dictionary with word as a key, and the idf as a value
dictionary = dict(zip(model.get_feature_names(), list(model.idf_)))

# %%
import warnings
warnings.filterwarnings("ignore")
# TF-IDF weighted Word2Vec
tfidf_feat = model.get_feature_names() # tfidf words/col-names


tfidf_sent_vectors_cv = []; # the tfidf-w2v for each sentence/review is stored in this list
row=0;
for sent in tqdm(list_of_sent): # for each review/sentence 
    sent_vec = np.zeros(50) # as word vectors are of zero length
    weight_sum =0; # num of words with a valid vector in the sentence/review
    for word in sent: # for each word in a review/sentence
        if word in w2v_words:
            vec = w2v_model.wv[word]
#             tf_idf = tf_idf_matrix[row, tfidf_feat.index(word)]
            # to reduce the computation we are 
            # dictionary[word] = idf value of word in whole courpus
            # sent.count(word) = tf valeus of word in this review
            tf_idf = dictionary[word]*(sent.count(word)/len(sent))
            sent_vec += (vec * tf_idf)
            weight_sum += tf_idf
    if weight_sum != 0:
        sent_vec /= weight_sum
    tfidf_sent_vectors_cv.append(sent_vec)
    row += 1
print(len(tfidf_sent_vectors_cv))
TFIDFW2VScorecv=final['Score'].values[51200:64000]
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 12800/12800 [00:10<00:00, 1217.83it/s]
# 12800

# %%
import warnings
warnings.filterwarnings("ignore")
#Creating W2V model
#WORD TO VECTOR
datawtovtest = final['CleanedText'].values[64000:]


i=0
list_of_sent=[]
for sent in datawtovtest:
    list_of_sent.append(sent.split())
w2v_model=Word2Vec(list_of_sent,min_count=5,size=50, workers=4)
w2v_words = list(w2v_model.wv.vocab)
print("number of words that occured minimum 5 times ",len(w2v_words))
print("sample words ", w2v_words[0:50])

sent_vectors_test = []; 
for sent in tqdm(list_of_sent): # for each review/sentence
    sent_vec = np.zeros(50) # as word vectors are of zero length
    for word in sent: # for each word in a review/sentence
        if word in w2v_words:
            vec = w2v_model.wv[word]
            sent_vec += vec
    sent_vectors_test.append(sent_vec)
print(len(sent_vectors_test))
W2VScoretest=final['Score'].values[64000:]
# Out:
# number of words that occured minimum 5 times  4917
# sample words  ['tortellini', 'dri', 'graini', 'come', 'small', 'box', 'couldnt', 'eat', 'flavor', 'strong', 'good', 'end', 'donat', 'remain', 'bought', 'time', 'ago', 'amazon', 'back', 'davinci', 'tri', 'barilla', 'brand', 'find', 'quit', 'tasti', 'lack', 'filler', 'use', 'great', 'butter', 'grate', 'chees', 'various', 'sauc', 'make', 'yummi', 'italian', 'salad', 'cut', 'hard', 'salami', 'chunk', 'pickl', 'veggi', 'marin', 'artichok', 'oliv', 'love', 'eas']
# 100%|██████████████████████████████████████████████████████████████████████████| 16000/16000 [00:09<00:00, 1661.17it/s]
# 16000

# %%
#TFIDF WEIGHTED W2V
import warnings
warnings.filterwarnings("ignore")

datatfidftest = final['CleanedText'].values[64000:]
model = TfidfVectorizer()
tf_idf_matrix = model.fit_transform(datatfidftest)
# we are converting a dictionary with word as a key, and the idf as a value
dictionary = dict(zip(model.get_feature_names(), list(model.idf_)))

# %%
import warnings
warnings.filterwarnings("ignore")
# TF-IDF weighted Word2Vec
tfidf_feat = model.get_feature_names() # tfidf words/col-names


tfidf_sent_vectors_test = []; # the tfidf-w2v for each sentence/review is stored in this list
row=0;
for sent in tqdm(list_of_sent): # for each review/sentence 
    sent_vec = np.zeros(50) # as word vectors are of zero length
    weight_sum =0; # num of words with a valid vector in the sentence/review
    for word in sent: # for each word in a review/sentence
        if word in w2v_words:
            vec = w2v_model.wv[word]
#             tf_idf = tf_idf_matrix[row, tfidf_feat.index(word)]
            # to reduce the computation we are 
            # dictionary[word] = idf value of word in whole courpus
            # sent.count(word) = tf valeus of word in this review
            tf_idf = dictionary[word]*(sent.count(word)/len(sent))
            sent_vec += (vec * tf_idf)
            weight_sum += tf_idf
    if weight_sum != 0:
        sent_vec /= weight_sum
    tfidf_sent_vectors_test.append(sent_vec)
    row += 1
TFIDFW2VScoretest=final['Score'].values[64000:]
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 16000/16000 [00:13<00:00, 1195.91it/s]

# %%
import warnings
warnings.filterwarnings("ignore")
#Train Test Split of TFIDF W2V data
#creating the model with TFIDF W2V and brute force KNN
X_train = tfidf_sent_vectors_train
X_test = tfidf_sent_vectors_test
X_cv = tfidf_sent_vectors_cv
Y_train = TFIDFW2VScoretrain
Y_test = TFIDFW2VScoretest
Y_cv =TFIDFW2VScorecv

# %%
with open('TFIDFW2Vfinal_Train_X.pkl', 'wb') as f:
    pickle.dump(X_train, f)
with open('TFIDFW2Vfinal_Train_Y.pkl', 'wb') as f:
    pickle.dump(Y_train, f)
with open('TFIDFW2Vfinal_CV_X.pkl', 'wb') as f:
    pickle.dump(X_cv, f)
with open('TFIDFW2Vfinal_CV_Y.pkl', 'wb') as f:
    pickle.dump(Y_cv, f)
with open('TFIDFW2Vfinal_Test_X.pkl', 'wb') as f:
    pickle.dump(X_test, f)
with open('TFIDFW2Vfinal_Test_Y.pkl', 'wb') as f:
    pickle.dump(Y_test, f)

# %%
import warnings
warnings.filterwarnings("ignore")
import warnings
warnings.filterwarnings("ignore")
#Brute Force KNN on TFIDFW2V
print("Running KNN using bRUTE FORCE on TFIDF W2V Vectorized data")

accuracy=0.0
neigh=1
f1score=0.0
kvalues=[]
error=[]
#Finding best parameters using Simple Cross Validation
for i in range(1,30,2):
    # instantiate learning model (k = 30)
    knn = KNeighborsClassifier(n_neighbors=i,algorithm='kd_tree')

    # fitting the model on crossvalidation train
    knn.fit(X_train, Y_train)

    # predict the response on the crossvalidation train
    pred = knn.predict(X_cv)

    # evaluate CV accuracy
    accu=accuracy_score(Y_cv, pred, normalize=True)
    acc = accuracy_score(Y_cv, pred, normalize=True) * float(100)
    print('\nCV accuracy for k = %d is %d%%' % (i, acc))
    f1=f1_score(Y_cv, pred, average='binary',pos_label='positive')
    print('\nCV f1_score for k = %d is %.10f' % (i, f1))
    #calculating error
    err=1-accu
    print("Error value : %.5f"%(err))
    error.append(err)
    kvalues.append(i)
    
    if (f1score<=f1):
        f1score=f1
        neigh=i
    else:
        pass

plt.figure()
plt.plot(kvalues,error)
plt.title("Error Graph")
plt.xlabel('K values')
plt.ylabel('Error')
plt.show()   
print ("The optimal value of k is %d"%(neigh))   
knn = KNeighborsClassifier(n_neighbors=neigh,algorithm='kd_tree')
knn.fit(X_train,Y_train)
pred = knn.predict(X_test)
acc = accuracy_score(Y_test, pred, normalize=True) * float(100)
print('\n****Test accuracy for k = %d is %d%%' % (neigh,acc))
f1=f1_score(Y_test, pred,average='binary',pos_label='positive')
print('\n Test f1_score for k = %d is %.10f' % (neigh, f1))
cm=confusion_matrix(Y_test,pred)
df_cm = pd.DataFrame(cm,index=["negative","positive"],columns=["negative","positive"])
plt.figure()
plt.title("Confusion matrix")
sns.heatmap(df_cm, annot=True,fmt="d")
# Out:
# Running KNN using bRUTE FORCE on TFIDF W2V Vectorized data
#
# CV accuracy for k = 1 is 74%
#
# CV f1_score for k = 1 is 0.8448775850
# Error value : 0.25492
#
# CV accuracy for k = 3 is 78%
#
# CV f1_score for k = 3 is 0.8776991472
# Error value : 0.21062
#
# CV accuracy for k = 5 is 80%
#
# CV f1_score for k = 5 is 0.8918954886
# Error value : 0.19039
#
# CV accuracy for k = 7 is 82%
#
# CV f1_score for k = 7 is 0.9001006432
# Error value : 0.17836
#
# CV accuracy for k = 9 is 83%
#
# CV f1_score for k = 9 is 0.9066597430
# Error value : 0.16852
#
# CV accuracy for k = 11 is 83%
#
# CV f1_score for k = 11 is 0.9105914718
# Error value : 0.16250
#
# CV accuracy for k = 13 is 84%
#
# CV f1_score for k = 13 is 0.9127344352
# Error value : 0.15922
#
# CV accuracy for k = 15 is 84%
#
# CV f1_score for k = 15 is 0.9137754230
# Error value : 0.15766
#
# CV accuracy for k = 17 is 84%
#
# CV f1_score for k = 17 is 0.9148138683
# Error value : 0.15625
#
# CV accuracy for k = 19 is 84%
#
# CV f1_score for k = 19 is 0.9153797064
# Error value : 0.15539
#
# CV accuracy for k = 21 is 84%
#
# CV f1_score for k = 21 is 0.9161882893
# Error value : 0.15398
#
# CV accuracy for k = 23 is 84%
#
# CV f1_score for k = 23 is 0.9173002591
# Error value : 0.15211
#
# CV accuracy for k = 25 is 84%
#
# CV f1_score for k = 25 is 0.9177838113
# Error value : 0.15141
#
# CV accuracy for k = 27 is 84%
#
# CV f1_score for k = 27 is 0.9181440326
# Error value : 0.15078
#
# CV accuracy for k = 29 is 84%
#
# CV f1_score for k = 29 is 0.9183872472
# Error value : 0.15039
# The optimal value of k is 29
#
# ****Test accuracy for k = 29 is 83%
#
#  Test f1_score for k = 29 is 0.9113941433

# %%
import warnings
warnings.filterwarnings("ignore")
print("Running KNN using KD Tree on TFIDF W2V Vectorized data")

accuracy=0.0
neigh=1
f1score=0.0
kvalues=[]
error=[]
#Finding best parameters using Simple Cross Validation
for i in range(1,30,2):
    # instantiate learning model (k = 30)
    knn = KNeighborsClassifier(n_neighbors=i,algorithm='kd_tree')

    # fitting the model on crossvalidation train
    knn.fit(X_train, Y_train)

    # predict the response on the crossvalidation train
    pred = knn.predict(X_cv)

    # evaluate CV accuracy
    accu=accuracy_score(Y_cv, pred, normalize=True)
    acc = accuracy_score(Y_cv, pred, normalize=True) * float(100)
    print('\nCV accuracy for k = %d is %d%%' % (i, acc))
    f1=f1_score(Y_cv, pred, average='binary',pos_label='positive')
    print('\nCV f1_score for k = %d is %.10f' % (i, f1))
    #calculating error
    err=1-accu
    print("Error value : %.5f"%(err))
    error.append(err)
    kvalues.append(i)
    
    if (f1score<=f1):
        f1score=f1
        neigh=i
    else:
        pass

plt.figure()
plt.plot(kvalues,error)
plt.title("Error Graph")
plt.xlabel('K values')
plt.ylabel('Error')
plt.show()   
print ("The optimal value of k is %d"%(neigh))   
knn = KNeighborsClassifier(n_neighbors=neigh,algorithm='kd_tree')
knn.fit(X_train,Y_train)
pred = knn.predict(X_test)
acc = accuracy_score(Y_test, pred, normalize=True) * float(100)
print('\n****Test accuracy for k = %d is %d%%' % (neigh,acc))
f1=f1_score(Y_test, pred,average='binary',pos_label='positive')
print('\n Test f1_score for k = %d is %.10f' % (neigh, f1))
cm=confusion_matrix(Y_test,pred)
df_cm = pd.DataFrame(cm,index=["negative","positive"],columns=["negative","positive"])
plt.figure()
plt.title("Confusion matrix")
sns.heatmap(df_cm, annot=True,fmt="d")
# Out:
# Running KNN using KD Tree on TFIDF W2V Vectorized data
#
# CV accuracy for k = 1 is 74%
#
# CV f1_score for k = 1 is 0.8448775850
# Error value : 0.25492
#
# CV accuracy for k = 3 is 78%
#
# CV f1_score for k = 3 is 0.8776991472
# Error value : 0.21062
#
# CV accuracy for k = 5 is 80%
#
# CV f1_score for k = 5 is 0.8918954886
# Error value : 0.19039
#
# CV accuracy for k = 7 is 82%
#
# CV f1_score for k = 7 is 0.9001006432
# Error value : 0.17836
#
# CV accuracy for k = 9 is 83%
#
# CV f1_score for k = 9 is 0.9066597430
# Error value : 0.16852
#
# CV accuracy for k = 11 is 83%
#
# CV f1_score for k = 11 is 0.9105914718
# Error value : 0.16250
#
# CV accuracy for k = 13 is 84%
#
# CV f1_score for k = 13 is 0.9127344352
# Error value : 0.15922
#
# CV accuracy for k = 15 is 84%
#
# CV f1_score for k = 15 is 0.9137754230
# Error value : 0.15766
#
# CV accuracy for k = 17 is 84%
#
# CV f1_score for k = 17 is 0.9148138683
# Error value : 0.15625
#
# CV accuracy for k = 19 is 84%
#
# CV f1_score for k = 19 is 0.9153797064
# Error value : 0.15539
#
# CV accuracy for k = 21 is 84%
#
# CV f1_score for k = 21 is 0.9161882893
# Error value : 0.15398
#
# CV accuracy for k = 23 is 84%
#
# CV f1_score for k = 23 is 0.9173002591
# Error value : 0.15211
#
# CV accuracy for k = 25 is 84%
#
# CV f1_score for k = 25 is 0.9177838113
# Error value : 0.15141
#
# CV accuracy for k = 27 is 84%
#
# CV f1_score for k = 27 is 0.9181440326
# Error value : 0.15078
#
# CV accuracy for k = 29 is 84%
#
# CV f1_score for k = 29 is 0.9183872472
# Error value : 0.15039
# The optimal value of k is 29
#
# ****Test accuracy for k = 29 is 83%
#
#  Test f1_score for k = 29 is 0.9113941433

# %% [markdown]
# ### Conclusion

# %%
from prettytable import PrettyTable

x = PrettyTable(["Vectorizer","Model","Hyperparameter/K","Accuracy","F1 Score"])
x.add_row(['BOW','Brute Force',29,'86%',0.927])
x.add_row(['BOW','KD Tree',29,'86%',0.927])
x.add_row(['TFIDF','Brute Force',29,'85%',0.922])
x.add_row(['TFIDF','KD Tree',29,'85%',0.922])
x.add_row(['W2V','Brute Force',29,'79%',0.881])
x.add_row(['W2V','KD Tree',29,'79%',0.881])
x.add_row(['TFIDFW2V','Brute Force',29,'83%',0.911])
x.add_row(['TFIDFW2V','KD Treee',29,'83%',0.911])
print(x)
# Out:
# +------------+-------------+------------------+----------+----------+
# | Vectorizer |    Model    | Hyperparameter/K | Accuracy | F1 Score |
# +------------+-------------+------------------+----------+----------+
# |    BOW     | Brute Force |        29        |   86%    |  0.927   |
# |    BOW     |   KD Tree   |        29        |   86%    |  0.927   |
# |   TFIDF    | Brute Force |        29        |   85%    |  0.922   |
# |   TFIDF    |   KD Tree   |        29        |   85%    |  0.922   |
# |    W2V     | Brute Force |        29        |   79%    |  0.881   |
# |    W2V     |   KD Tree   |        29        |   79%    |  0.881   |
# |  TFIDFW2V  | Brute Force |        29        |   83%    |  0.911   |
# |  TFIDFW2V  |   KD Treee  |        29        |   83%    |  0.911   |
# +------------+-------------+------------------+----------+----------+

# %% [markdown]
# Complete
